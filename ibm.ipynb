# %%
import pandas as pd
df_orders = pd.read_csv('superstore.csv')

# %% [markdown]
# Dropping The Row ID
# The "Row ID" column is not really that informative, I think it would be safe enough for us to simply just delete them. That way, it would give us much more clarity over our dataset.
#
# df_orders = is the name of the variable, that will be using throughout the example of this tutorial.
# .drop = the method being used to drop column.
# inplace=True = we used them to keep the changes onward

# %%
df_orders.drop("Row ID", axis=1, inplace=True)

# %%
df_orders
# Out:
#              Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0      CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# 1      CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# 2      CA-2017-138688   6/12/2017   6/16/2017    Second Class    DV-13045
# 3      US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# 4      US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# ...               ...         ...         ...             ...         ...
# 10795  US-2018-147886         NaN         NaN             NaN         NaN
# 10796  US-2018-147998         NaN         NaN             NaN         NaN
# 10797  US-2018-151127         NaN         NaN             NaN         NaN
# 10798  US-2018-155999         NaN         NaN             NaN         NaN
# 10799  US-2018-155999         NaN         NaN             NaN         NaN
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df_orders = pd.read_csv('superstore.csv', index_col='Order ID')

# %% [markdown]
# Drop the Row ID & Change The Index
# On to our another objective, what if we wish to combine both of the features, with dropping the 'Row ID' and to change the 'Index' columns at the same time, so that we could get even leaner dataset to work with. With that kind of objective, we might need to combine both of the syntax to achive our objective.
#
# 'df_orders.drop("Row ID", axis=1, inplace=True, index_col='Order ID')'
#
# '.drop()' = this method to drop a column from the dataset.
# 'axis=1' = is the attribution value, on the dataset.
# 'inplace=True' = we used them to keep our changes onward.
# 'index_col' = make the define column, as our newly active index column instead.

# %%
df_orders = pd.read_csv('superstore.csv', index_col='Order ID')
df_orders.drop("Row ID", axis=1, inplace=True)

# %%
df_orders
# Out:
#                 Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# CA-2017-138688   6/12/2017   6/16/2017    Second Class    DV-13045
# US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# ...                    ...         ...             ...         ...
# US-2018-147886         NaN         NaN             NaN         NaN
# US-2018-147998         NaN         NaN             NaN         NaN
# US-2018-151127         NaN         NaN             NaN         NaN
# US-2018-155999         NaN         NaN             NaN         NaN
# US-2018-155999         NaN         NaN             NaN         NaN
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# ...

# %%
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 5)

# %%
df_orders
# Out:
#                Order Date   Ship Date     Ship Mode Customer ID Customer Name  \
# Order ID
# CA-2017-152156  11/8/2017  11/11/2017  Second Class    CG-12520   Claire Gute
# CA-2017-152156  11/8/2017  11/11/2017  Second Class    CG-12520   Claire Gute
# ...                   ...         ...           ...         ...           ...
# US-2018-155999        NaN         NaN           NaN         NaN           NaN
# US-2018-155999        NaN         NaN           NaN         NaN           NaN
#
#                  Segment        Country       City     State  Postal Code  \
# Order ID
# CA-2017-152156  Consumer  United States  Henderson  Kentucky      42420.0
# CA-2017-152156  Consumer  United States  Henderson  Kentucky      42420.0
# ...                  ...            ...        ...       ...          ...
# US-2018-155999       NaN            NaN        NaN       NaN          NaN
# US-2018-155999       NaN            NaN        NaN       NaN          NaN
#
# ...

# %%
df_orders.head()
# Out:
#                 Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# CA-2017-138688   6/12/2017   6/16/2017    Second Class    DV-13045
# US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# CA-2017-152156      Claire Gute   Consumer  United States        Henderson
# CA-2017-152156      Claire Gute   Consumer  United States        Henderson
# CA-2017-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2016-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# US-2016-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# ...

# %%
df_orders.tail(5)
# Out:
#                Order Date Ship Date Ship Mode Customer ID Customer Name  \
# Order ID
# US-2018-147886        NaN       NaN       NaN         NaN           NaN
# US-2018-147998        NaN       NaN       NaN         NaN           NaN
# US-2018-151127        NaN       NaN       NaN         NaN           NaN
# US-2018-155999        NaN       NaN       NaN         NaN           NaN
# US-2018-155999        NaN       NaN       NaN         NaN           NaN
#
#                Segment Country City State  Postal Code Region Product ID  \
# Order ID
# US-2018-147886     NaN     NaN  NaN   NaN          NaN    NaN        NaN
# US-2018-147998     NaN     NaN  NaN   NaN          NaN    NaN        NaN
# US-2018-151127     NaN     NaN  NaN   NaN          NaN    NaN        NaN
# US-2018-155999     NaN     NaN  NaN   NaN          NaN    NaN        NaN
# US-2018-155999     NaN     NaN  NaN   NaN          NaN    NaN        NaN
#
# ...

# %%
df_orders.shape
# Out:
# (10800, 19)

# %%
df_orders.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_orders.columns = ['OrderDate', 'ShipDate', 'ShipMode', 'CustomerID', 'CustomerName', 'Segment' , 'Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName' , 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df_orders
# Out:
#                 OrderDate    ShipDate      ShipMode CustomerID CustomerName  \
# Order ID
# CA-2017-152156  11/8/2017  11/11/2017  Second Class   CG-12520  Claire Gute
# CA-2017-152156  11/8/2017  11/11/2017  Second Class   CG-12520  Claire Gute
# ...                   ...         ...           ...        ...          ...
# US-2018-155999        NaN         NaN           NaN        NaN          NaN
# US-2018-155999        NaN         NaN           NaN        NaN          NaN
#
#                  Segment        Country       City     State  PostalCode  \
# Order ID
# CA-2017-152156  Consumer  United States  Henderson  Kentucky     42420.0
# CA-2017-152156  Consumer  United States  Henderson  Kentucky     42420.0
# ...                  ...            ...        ...       ...         ...
# US-2018-155999       NaN            NaN        NaN       NaN         NaN
# US-2018-155999       NaN            NaN        NaN       NaN         NaN
#
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10800 entries, CA-2017-152156 to US-2018-155999
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   object
#  1   ShipDate      9994 non-null   object
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9983 non-null   float64
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   float64
# ...

# %%
# Let's try to change the datatypes of the following column in the dataset.
df_orders['OrderDate'] = df_orders['OrderDate'].astype('datetime64[ns]')
df_orders['ShipDate'] = df_orders['ShipDate'].astype('datetime64[ns]')
df_orders['PostalCode'] = df_orders['PostalCode'].astype('object')

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10800 entries, CA-2017-152156 to US-2018-155999
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   datetime64[ns]
#  1   ShipDate      9994 non-null   datetime64[ns]
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9983 non-null   object
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   float64
# ...

# %%
df_orders.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# ...             ...          ...          ...          ...
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000
#
# [8 rows x 4 columns]

# %%
df_orders.describe(include='all')
# Out:
# C:\Users\mahal\AppData\Local\Temp\ipykernel_7500\885882089.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_orders.describe(include='all')
# C:\Users\mahal\AppData\Local\Temp\ipykernel_7500\885882089.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_orders.describe(include='all')
#        OrderDate ShipDate ShipMode CustomerID CustomerName Segment Country  \
# count       9994     9994     9994       9994         9994    9994    9994
# unique      1236     1334        4        793          793       3       1
# ...

# %%
df_orders["Sales"].count()
# Out:
# 9994

# %%
df_orders["Sales"].mean()
# Out:
# 229.8580008304938

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10800 entries, CA-2017-152156 to US-2018-155999
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   datetime64[ns]
#  1   ShipDate      9994 non-null   datetime64[ns]
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9983 non-null   object
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   float64
# ...

# %%
df_orders.to_csv('df_orders_exported.csv')

# %% [markdown]
# # data cleaning

# %%
df_cleaned = pd.read_csv('df_orders_exported.csv')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      10800 non-null  object
#  1   OrderDate     9994 non-null   object
#  2   ShipDate      9994 non-null   object
#  3   ShipMode      9994 non-null   object
#  4   CustomerID    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9983 non-null   float64
#  11  Region        9994 non-null   object
#  12  ProductID     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   float64
# ...

# %%
# See the total rows and columns number
df_cleaned.shape
# Out:
# (10800, 20)

# %%
# Set the total rows and columns default numbers.
pd.set_option('display.max_columns', 21)
pd.set_option('display.max_rows', 5)

# %%
# Let's check the head dataset values.
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      10800 non-null  object
#  1   OrderDate     9994 non-null   object
#  2   ShipDate      9994 non-null   object
#  3   ShipMode      9994 non-null   object
#  4   CustomerID    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9983 non-null   float64
#  11  Region        9994 non-null   object
#  12  ProductID     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   float64
# ...

# %%
# Let's print the columns data types, along with the NaN records in the dataset and the number of cells in them.
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      10800 non-null  object
#  1   OrderDate     9994 non-null   object
#  2   ShipDate      9994 non-null   object
#  3   ShipMode      9994 non-null   object
#  4   CustomerID    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9983 non-null   float64
#  11  Region        9994 non-null   object
#  12  ProductID     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   float64
# ...

# %%
df_cleaned.isnull()
# Out:
#        Order ID  OrderDate  ShipDate  ShipMode  CustomerID  CustomerName  \
# 0         False      False     False     False       False         False
# 1         False      False     False     False       False         False
# ...         ...        ...       ...       ...         ...           ...
# 10798     False       True      True      True        True          True
# 10799     False       True      True      True        True          True
#
#        Segment  Country   City  State  PostalCode  Region  ProductID  \
# 0        False    False  False  False       False   False      False
# 1        False    False  False  False       False   False      False
# ...        ...      ...    ...    ...         ...     ...        ...
# 10798     True     True   True   True        True    True       True
# 10799     True     True   True   True        True    True       True
#
#        Category  SubCategory  ProductName  Sales  Quantity  Discount  Profit
# ...

# %%
df_cleaned.dropna(inplace=True)

# %%
df_cleaned.isnull()
# Out:
#       Order ID  OrderDate  ShipDate  ShipMode  CustomerID  CustomerName  \
# 0        False      False     False     False       False         False
# 1        False      False     False     False       False         False
# ...        ...        ...       ...       ...         ...           ...
# 9992     False      False     False     False       False         False
# 9993     False      False     False     False       False         False
#
#       Segment  Country   City  State  PostalCode  Region  ProductID  Category  \
# 0       False    False  False  False       False   False      False     False
# 1       False    False  False  False       False   False      False     False
# ...       ...      ...    ...    ...         ...     ...        ...       ...
# 9992    False    False  False  False       False   False      False     False
# 9993    False    False  False  False       False   False      False     False
#
# ...

# %%
df_cleaned['Revenue'] = df_cleaned['Sales'] - df_cleaned['Profit']

# %%
df_cleaned.head(3)
# Out:
#          Order ID   OrderDate    ShipDate      ShipMode CustomerID  \
# 0  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
# 1  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
# 2  CA-2017-138688  2017-06-12  2017-06-16  Second Class   DV-13045
#
#       CustomerName    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    PostalCode Region        ProductID         Category SubCategory  \
# 0     42420.0  South  FUR-BO-10001798        Furniture   Bookcases
# 1     42420.0  South  FUR-CH-10000454        Furniture      Chairs
# 2     90036.0   West  OFF-LA-10000240  Office Supplies      Labels
#
#                                          ProductName   Sales  Quantity  \
# ...

# %%
df_cleaned['GrossPrice'] = (df_cleaned['Revenue'] - df_cleaned['Profit']) / df_cleaned['Quantity']

# %%
df_cleaned['NetPrice'] = df_cleaned['GrossPrice'] - (df_cleaned['GrossPrice'] * df_cleaned['Discount'])

# %%
df_cleaned = df_cleaned.drop(columns=['GrossPrice'])

# %%
df_cleaned.to_csv('df_cleaning.csv', index = False)

# %% [markdown]
# # Data Grouping

# %%
import numpy as np

# %%
df_cleaning = pd.read_csv('df_cleaning.csv')

# %%
# Set the total rows and columns default numbers.
pd.set_option('display.max_columns', 23)
pd.set_option('display.max_rows', 5)

# %%
df_cleaning.columns
# Out:
# Index(['Order ID', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Revenue', 'NetPrice'],
#       dtype='object')

# %%
df_cleaning.dtypes
# Out:
# Order ID      object
# OrderDate     object
#               ...
# Revenue      float64
# NetPrice     float64
# Length: 22, dtype: object

# %%
df_cleaning[['Sales','Quantity','Profit']].groupby(['Profit'],as_index=True).sum().sort_values(by='Quantity',ascending=True)
# Out:
#              Sales  Quantity
# Profit
# 1.8872      13.480       1.0
# 4.4610      29.740       1.0
# ...            ...       ...
# 15.5520    842.400     130.0
# 0.0000   27686.847     255.0
#
# [7279 rows x 2 columns]

# %%
df_cleaning_groupby_salesQuantityProfit = df_cleaning[['Sales','Quantity','Profit']].groupby(['Profit'],as_index=True).sum().sort_values(by='Quantity',ascending=True)

# %%
df_cleaning_groupby_salesQuantityProfit.to_csv('df_cleaning_groupby_salesQuantityProfit.csv', index = False)

# %%
df_cleaning_groupby_salesQuantityProfit
# Out:
#              Sales  Quantity
# Profit
# 1.8872      13.480       1.0
# 4.4610      29.740       1.0
# ...            ...       ...
# 15.5520    842.400     130.0
# 0.0000   27686.847     255.0
#
# [7279 rows x 2 columns]

# %%
df_cleaning[['Sales', 'Discount']].groupby(['Sales'], as_index=True).sum().sort_values(by='Discount', ascending=False)
# Out:
#         Discount
# Sales
# 15.552       7.8
# 10.368       7.2
# ...          ...
# 8.750        0.0
# 83.420       0.0
#
# [5818 rows x 1 columns]

# %%
df_cleaning_groupby_salesDiscount = df_cleaning[['Sales', 'Discount']].groupby(['Sales'], as_index=False).mean().sort_values(by='Discount', ascending=False)

# %%
df_cleaning_groupby_salesDiscount
# Out:
#         Sales  Discount
# 42      1.788       0.8
# 0       0.444       0.8
# ...       ...       ...
# 3727  172.500       0.0
# 2909   83.420       0.0
#
# [5818 rows x 2 columns]

# %%
n_by_category = df_cleaning.groupby("Category")["SubCategory"].count()
n_by_category.head(10)
# Out:
# Category
# Furniture          2119
# Office Supplies    6020
# Technology         1844
# Name: SubCategory, dtype: int64

# %%
n_by_category_subcategory = df_cleaning.groupby(["Category", "SubCategory"])["Region"].count()

# %%
type(n_by_category_subcategory)
# Out:
# pandas.core.series.Series

# %%
n_by_category_subcategory.index[:5]
# Out:
# MultiIndex([(      'Furniture',   'Bookcases'),
#             (      'Furniture',      'Chairs'),
#             (      'Furniture', 'Furnishings'),
#             (      'Furniture',      'Tables'),
#             ('Office Supplies',  'Appliances')],
#            names=['Category', 'SubCategory'])

# %%
df_cleaning.groupby(["Category", "SubCategory"], as_index=False)["ProductName"].count()
# Out:
#       Category SubCategory  ProductName
# 0    Furniture   Bookcases          227
# 1    Furniture      Chairs          616
# ..         ...         ...          ...
# 15  Technology    Machines          115
# 16  Technology      Phones          888
#
# [17 rows x 3 columns]

# %%
df_cleaning.groupby(["Category", "SubCategory"], as_index=False)["Quantity"].count()
# Out:
#       Category SubCategory  Quantity
# 0    Furniture   Bookcases       227
# 1    Furniture      Chairs       616
# ..         ...         ...       ...
# 15  Technology    Machines       115
# 16  Technology      Phones       888
#
# [17 rows x 3 columns]

# %%
df_cleaning.groupby(["Category", "SubCategory"], as_index=False)["Quantity"].count()
# Out:
#       Category SubCategory  Quantity
# 0    Furniture   Bookcases       227
# 1    Furniture      Chairs       616
# ..         ...         ...       ...
# 15  Technology    Machines       115
# 16  Technology      Phones       888
#
# [17 rows x 3 columns]

# %%
df_cleaning.groupby("Category", sort=False)["SubCategory"].count()
# Out:
# Category
# Furniture          2119
# Office Supplies    6020
# Technology         1844
# Name: SubCategory, dtype: int64

# %%
by_category = df_cleaning.groupby("Category")
print(by_category)

# %%
for Category, frame in by_category:
    print(f"First 2 entries for {Category!r}")
    print("------------------------")
    print(frame.head(2), end="\n\n")
# Out:
# First 2 entries for 'Furniture'
# ------------------------
#          Order ID   OrderDate    ShipDate      ShipMode CustomerID  \
# 0  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
# 1  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
#
#   CustomerName   Segment        Country       City     State  PostalCode  \
# 0  Claire Gute  Consumer  United States  Henderson  Kentucky     42420.0
# 1  Claire Gute  Consumer  United States  Henderson  Kentucky     42420.0
#
#   Region        ProductID   Category SubCategory  \
# 0  South  FUR-BO-10001798  Furniture   Bookcases
# 1  South  FUR-CH-10000454  Furniture      Chairs
#
#                                          ProductName   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94       3.0
#
#    Discount    Profit   Revenue  NetPrice
# 0       0.0   41.9136  220.0464   89.0664
# ...

# %%
by_category.groups["Technology"]
# Out:
# Int64Index([   7,   11,   19,   26,   35,   40,   41,   44,   47,   48,
#             ...
#             9938, 9939, 9949, 9962, 9965, 9972, 9975, 9976, 9977, 9980],
#            dtype='int64', length=1844)

# %%
Category, frame = next(iter(by_category))  # First tuple from iterator
Category

frame.head(30)
# Out:
#            Order ID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0    CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 1    CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# ..              ...         ...         ...             ...        ...
# 124  US-2015-152030  2015-12-26  2015-12-28    Second Class   AD-10180
# 125  US-2015-134614  2015-09-20  2015-09-25  Standard Class   PF-19165
#
#        CustomerName      Segment        Country         City     State  \
# 0       Claire Gute     Consumer  United States    Henderson  Kentucky
# 1       Claire Gute     Consumer  United States    Henderson  Kentucky
# ..              ...          ...            ...          ...       ...
# 124  Alan Dominguez  Home Office  United States      Houston     Texas
# 125      Philip Fox     Consumer  United States  Bloomington  Illinois
#
#      PostalCode   Region        ProductID   Category SubCategory  \
# ...

# %%
frame["SubCategory"].count()  # Count for state == 'SubCategory'
# Out:
# 2119

# %% [markdown]
# # Data sorting

# %%
df_cleaning = pd.read_csv('df_cleaning.csv')

# %%
df_cleaning.loc[df_cleaning['Category'] == 'Office Supplies']
# Out:
#             Order ID   OrderDate    ShipDate        ShipMode CustomerID  \
# 2     CA-2017-138688  2017-06-12  2017-06-16    Second Class   DV-13045
# 4     US-2016-108966  2016-10-11  2016-10-18  Standard Class   SO-20335
# ...              ...         ...         ...             ...        ...
# 9981  CA-2018-121258  2018-02-26  2018-03-03  Standard Class   DB-13060
# 9982  CA-2018-119914  2018-05-04  2018-05-09    Second Class   CC-12220
#
#          CustomerName    Segment        Country             City       State  \
# 2     Darrin Van Huff  Corporate  United States      Los Angeles  California
# 4      Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...               ...        ...            ...              ...         ...
# 9981      Dave Brooks   Consumer  United States       Costa Mesa  California
# 9982     Chris Cortes   Consumer  United States      Westminster  California
#
# ...

# %%
df_cleaning.loc[df_cleaning['Category'] == 'Furniture']
# Out:
#             Order ID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0     CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 1     CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# ...              ...         ...         ...             ...        ...
# 9978  CA-2015-110422  2015-01-21  2015-01-23    Second Class   TB-21400
# 9979  CA-2018-121258  2018-02-26  2018-03-03  Standard Class   DB-13060
#
#           CustomerName   Segment        Country        City       State  \
# 0          Claire Gute  Consumer  United States   Henderson    Kentucky
# 1          Claire Gute  Consumer  United States   Henderson    Kentucky
# ...                ...       ...            ...         ...         ...
# 9978  Tom Boeckenhauer  Consumer  United States       Miami     Florida
# 9979       Dave Brooks  Consumer  United States  Costa Mesa  California
#
#       PostalCode Region        ProductID   Category  SubCategory  \
# ...

# %%
df_cleaning.loc[(df_cleaning['Category'] == 'Furniture') & (df_cleaning['SubCategory'] == 'Bookcases')]
# Out:
#             Order ID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0     CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 27    US-2016-150630  2016-09-17  2016-09-21  Standard Class   TB-21520
# ...              ...         ...         ...             ...        ...
# 9920  CA-2016-104948  2016-11-13  2016-11-17  Standard Class   KH-16510
# 9951  CA-2016-168088  2016-03-19  2016-03-22     First Class   CM-12655
#
#           CustomerName      Segment        Country            City  \
# 0          Claire Gute     Consumer  United States       Henderson
# 27     Tracy Blumstein     Consumer  United States    Philadelphia
# ...                ...          ...            ...             ...
# 9920     Keith Herrera     Consumer  United States  San Bernardino
# 9951  Corinna Mitchell  Home Office  United States         Houston
#
#              State  PostalCode   Region        ProductID   Category  \
# ...

# %%
df_Furniture_Bookcases = df_cleaning.loc[(df_cleaning['Category'] == 'Furniture') & (df_cleaning['SubCategory'] == 'Bookcases')]

# %%
df_Furniture_Bookcases
# Out:
#             Order ID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0     CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 27    US-2016-150630  2016-09-17  2016-09-21  Standard Class   TB-21520
# ...              ...         ...         ...             ...        ...
# 9920  CA-2016-104948  2016-11-13  2016-11-17  Standard Class   KH-16510
# 9951  CA-2016-168088  2016-03-19  2016-03-22     First Class   CM-12655
#
#           CustomerName      Segment        Country            City  \
# 0          Claire Gute     Consumer  United States       Henderson
# 27     Tracy Blumstein     Consumer  United States    Philadelphia
# ...                ...          ...            ...             ...
# 9920     Keith Herrera     Consumer  United States  San Bernardino
# 9951  Corinna Mitchell  Home Office  United States         Houston
#
#              State  PostalCode   Region        ProductID   Category  \
# ...

# %% [markdown]
# # data visualization

# %%
# Importing packages
import pandas as pd
import numpy as np

# Importing visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_cleaning = pd.read_csv('df_cleaning.csv')

# %%
plt.figure(figsize=(12,10))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
# Let's try to visualize the 'Segment' column from the dataset.

sns.set_style('whitegrid')
sns.countplot(x='Segment',data=df_cleaning, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>

# %%
# Let's try to visualize the 'Category' column from the dataset.

sns.set_style('whitegrid')
sns.countplot(x='Category',data=df_cleaning, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
# Let's try to visualize the 'SubCategory' column from the dataset.

sns.set_style('whitegrid')
sns.countplot(x='SubCategory',data=df_cleaning, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='SubCategory', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Region',data=df_cleaning, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='ShipMode',data=df_cleaning, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='ShipMode', ylabel='count'>

# %%
# Let's try to visualize the 'Region' column from the Shipmode column dataset standpoints.

region_hist = sns.FacetGrid(df_cleaning, col='ShipMode', palette='rainbow')
region_hist.map(plt.hist, 'Region')
region_hist.set_ylabels('Number')

# %%
# Let's try to visualize the 'Category' column from the Shipmode column dataset standpoints.

category_hist = sns.FacetGrid(df_cleaning, col='ShipMode', palette='rainbow')
category_hist.map(plt.hist, 'Category')
category_hist.set_ylabels('Number')

# %%
# Let's try to visualize the 'Category' column from the Shipmode column dataset standpoints.

pclass_age_grid = sns.FacetGrid(df_cleaning, col='Category', row='SubCategory', height=2.2, aspect=1.6)
pclass_age_grid.map(plt.hist, 'Segment')
pclass_age_grid.set_ylabels('Number')
pclass_age_grid.add_legend()

# %%
grid = sns.FacetGrid(df_cleaning, row='Category', col='SubCategory', height=2.2, aspect=1.6)
grid.map(sns.barplot, 'NetPrice', 'Segment', alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\mahal\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
